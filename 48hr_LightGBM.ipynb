# %%
# %pip install holidays
# %pip install lightgbm
# %pip install optuna
# Out:
# Requirement already satisfied: holidays in /Users/jakubgorecki/anaconda3/lib/python3.11/site-packages (0.84)
# Requirement already satisfied: python-dateutil in /Users/jakubgorecki/anaconda3/lib/python3.11/site-packages (from holidays) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/jakubgorecki/anaconda3/lib/python3.11/site-packages (from python-dateutil->holidays) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: lightgbm in /Users/jakubgorecki/anaconda3/lib/python3.11/site-packages (4.6.0)
# Requirement already satisfied: numpy>=1.17.0 in /Users/jakubgorecki/anaconda3/lib/python3.11/site-packages (from lightgbm) (1.23.5)
# Requirement already satisfied: scipy in /Users/jakubgorecki/anaconda3/lib/python3.11/site-packages (from lightgbm) (1.15.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: optuna in /Users/jakubgorecki/anaconda3/lib/python3.11/site-packages (4.6.0)
# Requirement already satisfied: alembic>=1.5.0 in /Users/jakubgorecki/anaconda3/lib/python3.11/site-packages (from optuna) (1.17.2)
# Requirement already satisfied: colorlog in /Users/jakubgorecki/anaconda3/lib/python3.11/site-packages (from optuna) (6.10.1)
# Requirement already satisfied: numpy in /Users/jakubgorecki/anaconda3/lib/python3.11/site-packages (from optuna) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /Users/jakubgorecki/anaconda3/lib/python3.11/site-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /Users/jakubgorecki/anaconda3/lib/python3.11/site-packages (from optuna) (2.0.43)
# Requirement already satisfied: tqdm in /Users/jakubgorecki/anaconda3/lib/python3.11/site-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /Users/jakubgorecki/anaconda3/lib/python3.11/site-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /Users/jakubgorecki/anaconda3/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /Users/jakubgorecki/anaconda3/lib/python3.11/site-packages (from alembic>=1.5.0->optuna) (4.13.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /Users/jakubgorecki/anaconda3/lib/python3.11/site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import holidays
import lightgbm as lgb
import numpy as np
import optuna
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# %%
# --- Configuration ---

DATA_PATH = "merged.csv"

TARGET_COLUMN = 'consumption'
GROUP_COLUMN = 'group_id'
TIME_COLUMN = 'measured_at'

# Define all your categorical features here
CATEGORICAL_FEATURES = [
    'group_id', 
    'm_area', 
    'region', 
    'municipality', 
    'segment', 
    'p_type', 
    'c_bucket'
]

# %%
df = pd.read_csv(DATA_PATH)

# %%
df.dtypes
# Out:
# measured_at      object
# group_id          int64
# consumption     float64
# eur_per_mwh     float64
# m_area           object
# region           object
# municipality     object
# segment          object
# p_type           object
# c_bucket         object
# avg_temp        float64
# avg_hum         float64
# wind            float64
# rain            float64
# air_pressure    float64
# dtype: object

# %%
def load_and_prep_data(data_path):
    """
    Loads the data, converts time column, and sets categorical dtypes.
    """
    print(f"Loading data from {data_path}...")
    df = pd.read_csv(data_path) 
    
    # We must do this per group to avoid data leaking between customers.
    # 'transform' applies the interpolation within each group and returns a Series
    # aligned with the original dataframe's index.
    # 'limit_direction="both"' fills NaNs at the very start or end of a group
    # by forward-filling or back-filling from the nearest valid price.
    df['eur_per_mwh'] = df.groupby(GROUP_COLUMN)['eur_per_mwh'].transform(
        lambda x: x.interpolate(method='linear', limit_direction='both')
    )

    df[TIME_COLUMN] = pd.to_datetime(df[TIME_COLUMN])

    for col in CATEGORICAL_FEATURES:
        if col in df.columns:
            df[col] = df[col].astype('category')
            
    # Sort data to ensure time-based features are correct
    df = df.sort_values(by=[GROUP_COLUMN, TIME_COLUMN])
    
    print("Data loaded and dtypes set.")
    return df

def create_time_features(df):
    """
    Creates new features from the main datetime column.
    INCLUDES CYCLIC FEATURES.
    """
    print("Creating time features (with cyclic)...")
    df_copy = df.copy()
    
    # Original features (we'll use them to create cyclic ones)
    hour = df_copy[TIME_COLUMN].dt.hour
    day_of_week = df_copy[TIME_COLUMN].dt.dayofweek
    day_of_month = df_copy[TIME_COLUMN].dt.day
    day_of_year = df_copy[TIME_COLUMN].dt.dayofyear
    month = df_copy[TIME_COLUMN].dt.month
    
    df_copy['year'] = df_copy[TIME_COLUMN].dt.year
    df_copy['is_weekend'] = (day_of_week >= 5).astype(int)
    
    fin_holidays = holidays.Finland()
    df_copy['is_holiday'] = df_copy[TIME_COLUMN].dt.date.apply(lambda x: x in fin_holidays).astype(int)
    
    # Hour of day (0-23)
    df_copy['hour_sin'] = np.sin(2 * np.pi * hour / 24.0)
    df_copy['hour_cos'] = np.cos(2 * np.pi * hour / 24.0)
    
    # Day of week (0-6)
    df_copy['day_of_week_sin'] = np.sin(2 * np.pi * day_of_week / 7.0)
    df_copy['day_of_week_cos'] = np.cos(2 * np.pi * day_of_week / 7.0)

    # Day of month (1-31)
    df_copy['day_of_month_sin'] = np.sin(2 * np.pi * (day_of_month - 1) / 31.0)
    df_copy['day_of_month_cos'] = np.cos(2 * np.pi * (day_of_month - 1) / 31.0)
    
    # Day of year (1-366)
    df_copy['day_of_year_sin'] = np.sin(2 * np.pi * (day_of_year - 1) / 366.0)
    df_copy['day_of_year_cos'] = np.cos(2 * np.pi * (day_of_year - 1) / 366.0)

    # Month (1-12)
    df_copy['month_sin'] = np.sin(2 * np.pi * (month - 1) / 12.0)
    df_copy['month_cos'] = np.cos(2 * np.pi * (month - 1) / 12.0)
    
    return df_copy

def create_lag_features(df, group_col, target, lags):
    """
    Creates lag features, grouped by each customer.
    """
    print(f"Creating lag features for lags: {lags}...")
    df_copy = df.copy()
    df_grouped = df_copy.groupby(group_col)
    
    for lag in lags:
        df_copy[f'{target}_lag_{lag}h'] = df_grouped[target].shift(lag)
        
    return df_copy

def create_rolling_features(df, group_col, target, windows, aggregations):
    """
    Creates rolling window features, grouped by each customer.
    """
    print(f"Creating rolling features for windows: {windows}...")
    df_copy = df.copy()
    
    for window in windows:
        for agg in aggregations:
            # The groupby operation is chained inside the rolling call
            # This is a more efficient way to do grouped rolling operations
            # We use reset_index() to align the new feature with the original dataframe
            rolling_feat = df_copy.groupby(group_col)[target] \
                                  .rolling(window=window, min_periods=1) \
                                  .agg(agg) \
                                  .reset_index(level=0, drop=True)
            
            df_copy[f'{target}_roll_{agg}_{window}h'] = rolling_feat
            
    return df_copy

# %%
# 1. Load and Prep
data = load_and_prep_data(DATA_PATH)

# Check the dtypes and for any missing values
data.info()
# Out:
# Loading data from merged.csv...
# Data loaded and dtypes set.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3679872 entries, 0 to 3679871
# Data columns (total 15 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   measured_at   datetime64[ns, UTC]
#  1   group_id      category
#  2   consumption   float64
#  3   eur_per_mwh   float64
#  4   m_area        category
#  5   region        category
#  6   municipality  category
#  7   segment       category
#  8   p_type        category
#  9   c_bucket      category
#  10  avg_temp      float64
#  11  avg_hum       float64
#  12  wind          float64
#  13  rain          float64
#  14  air_pressure  float64
# dtypes: category(7), datetime64[ns, UTC](1), float64(7)
# memory usage: 249.2 MB

# %%
# 2. Create Time Features
data = create_time_features(data)

# Display the new time features
print(data.columns[data.columns.str.contains('hour|day|month|year|week')])
data.head()
# Out:
# Creating time features (with cyclic)...
# Index(['year', 'is_weekend', 'is_holiday', 'hour_sin', 'hour_cos',
#        'day_of_week_sin', 'day_of_week_cos', 'day_of_month_sin',
#        'day_of_month_cos', 'day_of_year_sin', 'day_of_year_cos', 'month_sin',
#        'month_cos'],
#       dtype='object')
#                 measured_at group_id  consumption  eur_per_mwh  \
# 0 2021-01-01 00:00:00+00:00       28     7.010736        24.35
# 1 2021-01-01 01:00:00+00:00       28     6.600845        23.98
# 2 2021-01-01 02:00:00+00:00       28     6.468329        23.72
# 3 2021-01-01 03:00:00+00:00       28     6.712097        23.73
# 4 2021-01-01 04:00:00+00:00       28     6.418159        24.06
#
#             m_area      region municipality  segment      p_type c_bucket  \
# 0  Eastern Finland  Etelä-Savo   Etelä-Savo  Private  Spot Price     High
# 1  Eastern Finland  Etelä-Savo   Etelä-Savo  Private  Spot Price     High
# 2  Eastern Finland  Etelä-Savo   Etelä-Savo  Private  Spot Price     High
# 3  Eastern Finland  Etelä-Savo   Etelä-Savo  Private  Spot Price     High
# 4  Eastern Finland  Etelä-Savo   Etelä-Savo  Private  Spot Price     High
#
#    ...  hour_sin  hour_cos  day_of_week_sin  day_of_week_cos  \
# 0  ...  0.000000  1.000000        -0.433884        -0.900969
# 1  ...  0.258819  0.965926        -0.433884        -0.900969
# 2  ...  0.500000  0.866025        -0.433884        -0.900969
# 3  ...  0.707107  0.707107        -0.433884        -0.900969
# 4  ...  0.866025  0.500000        -0.433884        -0.900969
#
#    day_of_month_sin  day_of_month_cos  day_of_year_sin  day_of_year_cos  \
# 0               0.0               1.0              0.0              1.0
# 1               0.0               1.0              0.0              1.0
# 2               0.0               1.0              0.0              1.0
# 3               0.0               1.0              0.0              1.0
# 4               0.0               1.0              0.0              1.0
#
#    month_sin  month_cos
# 0        0.0        1.0
# 1        0.0        1.0
# 2        0.0        1.0
# 3        0.0        1.0
# 4        0.0        1.0
#
# [5 rows x 28 columns]

# %%
# 3. Create Lag Features
lag_list = [1, 2, 3, 6, 12, 24, 48, 168]
data = create_lag_features(data, GROUP_COLUMN, TARGET_COLUMN, lag_list)

# Check the end of a single group's data to see the lags
data[data[GROUP_COLUMN] == data[GROUP_COLUMN].unique()[0]].tail()
# Out:
# Creating lag features for lags: [1, 2, 3, 6, 12, 24, 48, 168]...
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = df_copy.groupby(group_col)
#                     measured_at group_id  consumption  eur_per_mwh  \
# 32851 2024-09-30 19:00:00+00:00       28     6.234852         4.19
# 32852 2024-09-30 20:00:00+00:00       28     5.925762         2.03
# 32853 2024-09-30 21:00:00+00:00       28     5.419120         0.00
# 32854 2024-09-30 22:00:00+00:00       28     5.177524         0.01
# 32855 2024-09-30 23:00:00+00:00       28     4.944352         0.01
#
#                 m_area      region municipality  segment      p_type c_bucket  \
# 32851  Eastern Finland  Etelä-Savo   Etelä-Savo  Private  Spot Price     High
# 32852  Eastern Finland  Etelä-Savo   Etelä-Savo  Private  Spot Price     High
# 32853  Eastern Finland  Etelä-Savo   Etelä-Savo  Private  Spot Price     High
# 32854  Eastern Finland  Etelä-Savo   Etelä-Savo  Private  Spot Price     High
# 32855  Eastern Finland  Etelä-Savo   Etelä-Savo  Private  Spot Price     High
#
#        ...  month_sin  month_cos  consumption_lag_1h  consumption_lag_2h  \
# 32851  ...  -0.866025       -0.5            5.625254            5.351200
# 32852  ...  -0.866025       -0.5            6.234852            5.625254
# 32853  ...  -0.866025       -0.5            5.925762            6.234852
# 32854  ...  -0.866025       -0.5            5.419120            5.925762
# 32855  ...  -0.866025       -0.5            5.177524            5.419120
#
#        consumption_lag_3h  consumption_lag_6h  consumption_lag_12h  \
# 32851            4.611995            3.531831             3.507821
# 32852            5.351200            3.679196             3.353279
# 32853            5.625254            4.109394             3.208446
# 32854            6.234852            4.611995             3.191845
# 32855            5.925762            5.351200             3.154596
#
#        consumption_lag_24h  consumption_lag_48h  consumption_lag_168h
# 32851             5.559985             4.625679              5.347109
# 32852             5.239241             4.431405              5.051069
# 32853             4.554825             3.846092              4.464691
# 32854             4.059698             3.491137              4.050641
# 32855             3.979015             3.436034              3.864060
#
# [5 rows x 36 columns]

# %%
# 4. Create Rolling Features (Daily and Weekly trends)
window_list = [24, 168]
agg_list = ['mean', 'std']
data = create_rolling_features(data, GROUP_COLUMN, TARGET_COLUMN, window_list, agg_list)

# Check the new rolling features
data.head()
# Out:
# Creating rolling features for windows: [24, 168]...
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
#                 measured_at group_id  consumption  eur_per_mwh  \
# 0 2021-01-01 00:00:00+00:00       28     7.010736        24.35
# 1 2021-01-01 01:00:00+00:00       28     6.600845        23.98
# 2 2021-01-01 02:00:00+00:00       28     6.468329        23.72
# 3 2021-01-01 03:00:00+00:00       28     6.712097        23.73
# 4 2021-01-01 04:00:00+00:00       28     6.418159        24.06
#
#             m_area      region municipality  segment      p_type c_bucket  \
# 0  Eastern Finland  Etelä-Savo   Etelä-Savo  Private  Spot Price     High
# 1  Eastern Finland  Etelä-Savo   Etelä-Savo  Private  Spot Price     High
# 2  Eastern Finland  Etelä-Savo   Etelä-Savo  Private  Spot Price     High
# 3  Eastern Finland  Etelä-Savo   Etelä-Savo  Private  Spot Price     High
# 4  Eastern Finland  Etelä-Savo   Etelä-Savo  Private  Spot Price     High
#
#    ...  consumption_lag_3h  consumption_lag_6h  consumption_lag_12h  \
# 0  ...                 NaN                 NaN                  NaN
# 1  ...                 NaN                 NaN                  NaN
# 2  ...                 NaN                 NaN                  NaN
# 3  ...            7.010736                 NaN                  NaN
# 4  ...            6.600845                 NaN                  NaN
#
#    consumption_lag_24h  consumption_lag_48h  consumption_lag_168h  \
# 0                  NaN                  NaN                   NaN
# 1                  NaN                  NaN                   NaN
# 2                  NaN                  NaN                   NaN
# 3                  NaN                  NaN                   NaN
# 4                  NaN                  NaN                   NaN
#
#    consumption_roll_mean_24h  consumption_roll_std_24h  \
# 0                   7.010736                       NaN
# 1                   6.805790                  0.289837
# 2                   6.693303                  0.282776
# 3                   6.698002                  0.231077
# 4                   6.642033                  0.236029
#
#    consumption_roll_mean_168h  consumption_roll_std_168h
# 0                    7.010736                        NaN
# 1                    6.805790                   0.289837
# 2                    6.693303                   0.282776
# 3                    6.698002                   0.231077
# 4                    6.642033                   0.236029
#
# [5 rows x 40 columns]

# %%
print("--- Creating Price Features ---")

# 1. Define price lag list
price_lag_list = [1, 24, 168]

print(f"Creating price lag features for lags: {price_lag_list}...")
data = create_lag_features(data, GROUP_COLUMN, 'eur_per_mwh', price_lag_list)


# 2. Define price rolling windows
price_window_list = [24, 168]
price_agg_list = ['mean', 'std']

print(f"Creating price rolling features for windows: {price_window_list}...")
data = create_rolling_features(data, GROUP_COLUMN, 'eur_per_mwh', price_window_list, price_agg_list)

print("Price features created.")
# Out:
# --- Creating Price Features ---
# Creating price lag features for lags: [1, 24, 168]...
# Creating lag features for lags: [1, 24, 168]...
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = df_copy.groupby(group_col)
# Creating price rolling features for windows: [24, 168]...
# Creating rolling features for windows: [24, 168]...
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# Price features created.

# %%
print("--- Creating Weather Features ---")

WEATHER_COLUMNS = ['avg_temp', 'avg_hum', 'wind', 'rain', 'air_pressure']
weather_lag_list = [1, 24, 168]
weather_window_list = [24, 168]
weather_agg_list = ['mean', 'std']

for col in WEATHER_COLUMNS:
    if col not in data.columns:
        print(f"Warning: Weather column '{col}' not found. Skipping.")
        continue
    
    print(f"Creating features for: {col}")
    # Create Lags
    data = create_lag_features(data, GROUP_COLUMN, col, weather_lag_list)
    
    # Create Rolling Windows
    data = create_rolling_features(data, GROUP_COLUMN, col, weather_window_list, weather_agg_list)

print("Weather features created.")
# Out:
# --- Creating Weather Features ---
# Creating features for: avg_temp
# Creating lag features for lags: [1, 24, 168]...
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = df_copy.groupby(group_col)
# Creating rolling features for windows: [24, 168]...
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# Creating features for: avg_hum
# Creating lag features for lags: [1, 24, 168]...
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = df_copy.groupby(group_col)
# Creating rolling features for windows: [24, 168]...
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# Creating features for: wind
# Creating lag features for lags: [1, 24, 168]...
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = df_copy.groupby(group_col)
# Creating rolling features for windows: [24, 168]...
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# Creating features for: rain
# Creating lag features for lags: [1, 24, 168]...
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = df_copy.groupby(group_col)
# Creating rolling features for windows: [24, 168]...
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# Creating features for: air_pressure
# Creating lag features for lags: [1, 24, 168]...
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = df_copy.groupby(group_col)
# Creating rolling features for windows: [24, 168]...
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# Weather features created.

# %%
# 5. Drop rows with NaNs created by lags/rolling windows
original_rows = data.shape[0]
data = data.dropna()
new_rows = data.shape[0]

print(f"Dropped {original_rows - new_rows} rows due to NaN values.")
print(f"Original rows: {original_rows}, New rows: {new_rows}")
# Out:
# Dropped 18816 rows due to NaN values.
# Original rows: 3679872, New rows: 3661056

# %%
print("--- Final DataFrame Info ---")
data.info()

print("\n--- Final DataFrame (Sample) ---")
# Show a random sample to see different groups and times
data.sample(10)
# Out:
# --- Final DataFrame Info ---
# <class 'pandas.core.frame.DataFrame'>
# Index: 3661056 entries, 168 to 3679871
# Data columns (total 82 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   measured_at                  datetime64[ns, UTC]
#  1   group_id                     category
#  2   consumption                  float64
#  3   eur_per_mwh                  float64
#  4   m_area                       category
#  5   region                       category
#  6   municipality                 category
#  7   segment                      category
#  8   p_type                       category
#  9   c_bucket                     category
#  10  avg_temp                     float64
#  11  avg_hum                      float64
#  12  wind                         float64
#  13  rain                         float64
#  14  air_pressure                 float64
#  15  year                         int32
#  16  is_weekend                   int64
#  17  is_holiday                   int64
#  18  hour_sin                     float64
#  19  hour_cos                     float64
#  20  day_of_week_sin              float64
#  21  day_of_week_cos              float64
#  22  day_of_month_sin             float64
#  23  day_of_month_cos             float64
#  24  day_of_year_sin              float64
#  25  day_of_year_cos              float64
#  26  month_sin                    float64
#  27  month_cos                    float64
#  28  consumption_lag_1h           float64
#  29  consumption_lag_2h           float64
#  30  consumption_lag_3h           float64
#  31  consumption_lag_6h           float64
#  32  consumption_lag_12h          float64
#  33  consumption_lag_24h          float64
#  34  consumption_lag_48h          float64
#  35  consumption_lag_168h         float64
#  36  consumption_roll_mean_24h    float64
#  37  consumption_roll_std_24h     float64
#  38  consumption_roll_mean_168h   float64
#  39  consumption_roll_std_168h    float64
#  40  eur_per_mwh_lag_1h           float64
#  41  eur_per_mwh_lag_24h          float64
#  42  eur_per_mwh_lag_168h         float64
#  43  eur_per_mwh_roll_mean_24h    float64
#  44  eur_per_mwh_roll_std_24h     float64
#  45  eur_per_mwh_roll_mean_168h   float64
#  46  eur_per_mwh_roll_std_168h    float64
#  47  avg_temp_lag_1h              float64
#  48  avg_temp_lag_24h             float64
#  49  avg_temp_lag_168h            float64
#  50  avg_temp_roll_mean_24h       float64
#  51  avg_temp_roll_std_24h        float64
#  52  avg_temp_roll_mean_168h      float64
#  53  avg_temp_roll_std_168h       float64
#  54  avg_hum_lag_1h               float64
#  55  avg_hum_lag_24h              float64
#  56  avg_hum_lag_168h             float64
#  57  avg_hum_roll_mean_24h        float64
#  58  avg_hum_roll_std_24h         float64
#  59  avg_hum_roll_mean_168h       float64
#  60  avg_hum_roll_std_168h        float64
#  61  wind_lag_1h                  float64
#  62  wind_lag_24h                 float64
#  63  wind_lag_168h                float64
#  64  wind_roll_mean_24h           float64
#  65  wind_roll_std_24h            float64
#  66  wind_roll_mean_168h          float64
#  67  wind_roll_std_168h           float64
#  68  rain_lag_1h                  float64
#  69  rain_lag_24h                 float64
#  70  rain_lag_168h                float64
#  71  rain_roll_mean_24h           float64
#  72  rain_roll_std_24h            float64
#  73  rain_roll_mean_168h          float64
#  74  rain_roll_std_168h           float64
#  75  air_pressure_lag_1h          float64
#  76  air_pressure_lag_24h         float64
#  77  air_pressure_lag_168h        float64
#  78  air_pressure_roll_mean_24h   float64
#  79  air_pressure_roll_std_24h    float64
#  80  air_pressure_roll_mean_168h  float64
#  81  air_pressure_roll_std_168h   float64
# dtypes: category(7), datetime64[ns, UTC](1), float64(71), int32(1), int64(2)
# memory usage: 2.1 GB
#
# --- Final DataFrame (Sample) ---
#                       measured_at group_id  consumption  eur_per_mwh  \
# 2175444 2021-10-17 12:00:00+00:00      404     0.280530        56.75
# 187827  2023-09-09 03:00:00+00:00       38     0.350873         0.00
# 2774714 2022-09-10 02:00:00+00:00      582     0.127706        95.06
# 1529849 2023-02-09 17:00:00+00:00      346     0.327415        26.17
# 3564831 2022-11-14 15:00:00+00:00      709     0.307033       212.44
# 3469491 2023-03-29 03:00:00+00:00      706     0.408933        65.35
# 2728313 2021-02-22 17:00:00+00:00      581     5.346575        60.02
# 1335190 2023-05-23 22:00:00+00:00      302     0.325737         2.43
# 2736600 2022-02-03 00:00:00+00:00      581     5.143495       135.89
# 119136  2023-05-08 00:00:00+00:00       36     0.368352        56.68
#
#                              m_area           region     municipality  \
# 2175444            Southern Finland          Uusimaa            Espoo
# 187827              Eastern Finland  Pohjois-Karjala          Joensuu
# 2774714  Western and Inland Finland  Etelä-Pohjanmaa  Etelä-Pohjanmaa
# 1529849            Southern Finland      Päijät-Häme            Lahti
# 3564831  Western and Inland Finland        Pirkanmaa          Tampere
# 3469491  Western and Inland Finland        Pirkanmaa          Tampere
# 2728313  Western and Inland Finland  Etelä-Pohjanmaa  Etelä-Pohjanmaa
# 1335190            Southern Finland       Kanta-Häme       Kanta-Häme
# 2736600  Western and Inland Finland  Etelä-Pohjanmaa  Etelä-Pohjanmaa
# 119136              Eastern Finland  Pohjois-Karjala          Joensuu
#
#             segment          p_type c_bucket  ...  rain_roll_std_24h  \
# 2175444     Private  Variable Price      Low  ...           0.083297
# 187827      Private     Fixed Price   Medium  ...           0.000000
# 2774714     Private      Spot Price      Low  ...           0.000000
# 1529849     Private     Flat/Hybrid      Low  ...           0.000000
# 3564831     Private  Variable Price      Low  ...           0.000000
# 3469491     Private     Flat/Hybrid   Medium  ...           0.000000
# 2728313     Private      Spot Price     High  ...           0.000000
# 1335190     Private     Flat/Hybrid   Medium  ...           0.065801
# 2736600     Private      Spot Price     High  ...           0.000000
# 119136   Enterprise  Variable Price      Low  ...           0.000000
#
#          rain_roll_mean_168h  rain_roll_std_168h  air_pressure_lag_1h  \
# 2175444             0.113690            0.476128               1003.7
# 187827              0.052976            0.288071               1020.7
# 2774714             0.000000            0.000000               1024.2
# 1529849             0.002976            0.031766               1016.6
# 3564831             0.000000            0.000000               1024.9
# 3469491             0.000000            0.000000               1010.7
# 2728313             0.000000            0.000000               1028.9
# 1335190             0.004167            0.029677               1017.0
# 2736600             0.000000            0.000000               1007.1
# 119136              0.122024            0.378846               1026.6
#
#          air_pressure_lag_24h  air_pressure_lag_168h  \
# 2175444                 999.0                 1025.7
# 187827                 1019.8                 1011.9
# 2774714                1026.5                 1022.9
# 1529849                1031.9                 1007.7
# 3564831                1028.7                 1003.6
# 3469491                1005.9                 1007.4
# 2728313                1017.5                 1024.9
# 1335190                1019.0                 1007.6
# 2736600                 997.0                  999.7
# 119136                 1028.0                 1008.3
#
#          air_pressure_roll_mean_24h  air_pressure_roll_std_24h  \
# 2175444                 1000.475000                   1.744121
# 187827                  1019.579167                   0.521686
# 2774714                 1025.320833                   0.974447
# 1529849                 1024.141667                   5.153126
# 3564831                 1028.408333                   1.724483
# 3469491                 1009.091667                   1.493731
# 2728313                 1021.025000                   4.892519
# 1335190                 1017.433333                   0.663762
# 2736600                 1001.966667                   3.513040
# 119136                  1027.704167                   0.991915
#
#          air_pressure_roll_mean_168h  air_pressure_roll_std_168h
# 2175444                  1006.991071                    8.056298
# 187827                   1016.554762                    4.485637
# 2774714                  1025.074405                    3.422749
# 1529849                  1026.241667                    8.045041
# 3564831                  1009.658929                   10.506476
# 3469491                   997.614881                    7.702513
# 2728313                  1019.869048                    5.235804
# 1335190                  1023.540476                    7.890533
# 2736600                   995.976786                    9.094145
# 119136                   1019.201190                    9.622311
#
# [10 rows x 82 columns]

# %%
# Save the processed data to a new file (parquet is fast and efficient)
PROCESSED_DATA_PATH = "processed_energy_data.parquet"
data.to_parquet(PROCESSED_DATA_PATH)

print(f"Processed data saved to {PROCESSED_DATA_PATH}")
# Out:
# Processed data saved to processed_energy_data.parquet

# %%
# 1. Define the Cutoff Date (Last 14 days of the dataset)
# This dynamic approach works regardless of what specific year your data ends in
max_date = data[TIME_COLUMN].max()
cutoff_date = max_date - pd.Timedelta(days=14)

print(f"Dataset End Date: {max_date}")
print(f"Validation Split Date: {cutoff_date}")

# 2. Perform the Split
train = data[data[TIME_COLUMN] <= cutoff_date]
val = data[data[TIME_COLUMN] > cutoff_date]

# 3. Define Features (X) and Target (y)
# We exclude the target itself and the raw timestamp
features = [col for col in data.columns if col not in [TARGET_COLUMN, TIME_COLUMN]]

X_train = train[features]
y_train = train[TARGET_COLUMN]

X_val = val[features]
y_val = val[TARGET_COLUMN]

print("\n--- Split Shapes ---")
print(f"Training Data:   {X_train.shape} rows")
print(f"Validation Data: {X_val.shape} rows")
print(f"Features used:   {len(features)}")
print(f"Features list:   {features}")
# Out:
# Dataset End Date: 2024-09-30 23:00:00+00:00
# Validation Split Date: 2024-09-16 23:00:00+00:00
#
# --- Split Shapes ---
# Training Data:   (3623424, 80) rows
# Validation Data: (37632, 80) rows
# Features used:   80
# Features list:   ['group_id', 'eur_per_mwh', 'm_area', 'region', 'municipality', 'segment', 'p_type', 'c_bucket', 'avg_temp', 'avg_hum', 'wind', 'rain', 'air_pressure', 'year', 'is_weekend', 'is_holiday', 'hour_sin', 'hour_cos', 'day_of_week_sin', 'day_of_week_cos', 'day_of_month_sin', 'day_of_month_cos', 'day_of_year_sin', 'day_of_year_cos', 'month_sin', 'month_cos', 'consumption_lag_1h', 'consumption_lag_2h', 'consumption_lag_3h', 'consumption_lag_6h', 'consumption_lag_12h', 'consumption_lag_24h', 'consumption_lag_48h', 'consumption_lag_168h', 'consumption_roll_mean_24h', 'consumption_roll_std_24h', 'consumption_roll_mean_168h', 'consumption_roll_std_168h', 'eur_per_mwh_lag_1h', 'eur_per_mwh_lag_24h', 'eur_per_mwh_lag_168h', 'eur_per_mwh_roll_mean_24h', 'eur_per_mwh_roll_std_24h', 'eur_per_mwh_roll_mean_168h', 'eur_per_mwh_roll_std_168h', 'avg_temp_lag_1h', 'avg_temp_lag_24h', 'avg_temp_lag_168h', 'avg_temp_roll_mean_24h', 'avg_temp_roll_std_24h', 'avg_temp_roll_mean_168h', 'avg_temp_roll_std_168h', 'avg_hum_lag_1h', 'avg_hum_lag_24h', 'avg_hum_lag_168h', 'avg_hum_roll_mean_24h', 'avg_hum_roll_std_24h', 'avg_hum_roll_mean_168h', 'avg_hum_roll_std_168h', 'wind_lag_1h', 'wind_lag_24h', 'wind_lag_168h', 'wind_roll_mean_24h', 'wind_roll_std_24h', 'wind_roll_mean_168h', 'wind_roll_std_168h', 'rain_lag_1h', 'rain_lag_24h', 'rain_lag_168h', 'rain_roll_mean_24h', 'rain_roll_std_24h', 'rain_roll_mean_168h', 'rain_roll_std_168h', 'air_pressure_lag_1h', 'air_pressure_lag_24h', 'air_pressure_lag_168h', 'air_pressure_roll_mean_24h', 'air_pressure_roll_std_24h', 'air_pressure_roll_mean_168h', 'air_pressure_roll_std_168h']

# %%
# Create the LightGBM Dataset objects
# This effectively "compiles" the data for the model
train_data = lgb.Dataset(
    X_train, 
    label=y_train, 
    categorical_feature=CATEGORICAL_FEATURES,
    free_raw_data=False # Keeps the raw data in memory just in case we need to inspect
)

val_data = lgb.Dataset(
    X_val, 
    label=y_val, 
    categorical_feature=CATEGORICAL_FEATURES,
    reference=train_data, # Validation data must use the same bins/categories as training
    free_raw_data=False
)

print("LightGBM Datasets created successfully.")
# Out:
# LightGBM Datasets created successfully.

# %%
def objective(trial):
    # Define the search space for parameters
    params = {
        'objective': 'regression_l1',
        'metric': 'rmse',
        'n_estimators': 1000,
        'n_jobs': -1,
        'seed': 42,
        'verbose': -1, # Suppress logs during trials
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1, log=True),
        'num_leaves': trial.suggest_int('num_leaves', 20, 150),
        'max_depth': trial.suggest_int('max_depth', -1, 50),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0), # 'bagging_fraction'
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.4, 1.0) # 'feature_fraction'
    }

    # Re-run the training with these new params
    model_tune = lgb.train(
        params=params,
        train_set=train_data,
        valid_sets=[val_data], # We only need validation set for scoring
        valid_names=['validation'],
        callbacks=[lgb.early_stopping(50, verbose=False)]
    )

    # Return the score to minimize
    return model_tune.best_score['validation']['rmse']

# --- Start the Tuning ---
print("Starting Optuna hyperparameter search...")

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50) # Run 50 different trials

print("\n--- Tuning Complete ---")
print("Best trial:")
print(f"  Value (RMSE): {study.best_value:.4f}")
print("  Best Params: ")
for key, value in study.best_params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2025-11-15 22:11:21,233] A new study created in memory with name: no-name-77b96865-e2bc-4173-92fa-46c0410b408b
# Starting Optuna hyperparameter search...
# [I 2025-11-15 22:14:41,225] Trial 0 finished with value: 0.057906738445651564 and parameters: {'learning_rate': 0.027000792698870114, 'num_leaves': 119, 'max_depth': 32, 'subsample': 0.8979603643198104, 'colsample_bytree': 0.7940417404786313}. Best is trial 0 with value: 0.057906738445651564.
# [I 2025-11-15 22:16:07,510] Trial 1 finished with value: 0.09308999172111423 and parameters: {'learning_rate': 0.03064059744920763, 'num_leaves': 43, 'max_depth': 2, 'subsample': 0.661538269513958, 'colsample_bytree': 0.8781813182998747}. Best is trial 0 with value: 0.057906738445651564.
# [I 2025-11-15 22:19:33,005] Trial 2 finished with value: 0.052720598242332765 and parameters: {'learning_rate': 0.04458413621309797, 'num_leaves': 149, 'max_depth': 22, 'subsample': 0.6706900172521421, 'colsample_bytree': 0.5967325773976782}. Best is trial 2 with value: 0.052720598242332765.
# [I 2025-11-15 22:22:39,941] Trial 3 finished with value: 0.06067745745752501 and parameters: {'learning_rate': 0.027441495264863777, 'num_leaves': 130, 'max_depth': 27, 'subsample': 0.823319093519634, 'colsample_bytree': 0.6282987303305383}. Best is trial 2 with value: 0.052720598242332765.
# [I 2025-11-15 22:25:13,460] Trial 4 finished with value: 0.06130091336845159 and parameters: {'learning_rate': 0.04262420921257732, 'num_leaves': 126, 'max_depth': 8, 'subsample': 0.7291947299920684, 'colsample_bytree': 0.5842518365728089}. Best is trial 2 with value: 0.052720598242332765.
# [I 2025-11-15 22:28:05,654] Trial 5 finished with value: 0.06649693153994408 and parameters: {'learning_rate': 0.019694015209032523, 'num_leaves': 90, 'max_depth': 38, 'subsample': 0.6072573545801456, 'colsample_bytree': 0.6678583025048268}. Best is trial 2 with value: 0.052720598242332765.
# [I 2025-11-15 22:30:26,470] Trial 6 finished with value: 0.062245233775879975 and parameters: {'learning_rate': 0.03122975338074621, 'num_leaves': 98, 'max_depth': 33, 'subsample': 0.8562328909768111, 'colsample_bytree': 0.40209464970826814}. Best is trial 2 with value: 0.052720598242332765.
# [I 2025-11-15 22:33:44,029] Trial 7 finished with value: 0.05418754938399092 and parameters: {'learning_rate': 0.049292843185298724, 'num_leaves': 147, 'max_depth': 12, 'subsample': 0.6160003197772886, 'colsample_bytree': 0.9304464831131514}. Best is trial 2 with value: 0.052720598242332765.
# [I 2025-11-15 22:35:50,914] Trial 8 finished with value: 0.06468460026154574 and parameters: {'learning_rate': 0.03811792447198252, 'num_leaves': 52, 'max_depth': 19, 'subsample': 0.9585989427128481, 'colsample_bytree': 0.4091362995787474}. Best is trial 2 with value: 0.052720598242332765.
# [I 2025-11-15 22:38:15,396] Trial 9 finished with value: 0.06072190731312329 and parameters: {'learning_rate': 0.046285196252585675, 'num_leaves': 67, 'max_depth': 15, 'subsample': 0.7336249168540169, 'colsample_bytree': 0.47533662307503555}. Best is trial 2 with value: 0.052720598242332765.
# [I 2025-11-15 22:40:27,291] Trial 10 finished with value: 0.06170302079720833 and parameters: {'learning_rate': 0.09499038344184704, 'num_leaves': 30, 'max_depth': 49, 'subsample': 0.7392128684418952, 'colsample_bytree': 0.7532819650363537}. Best is trial 2 with value: 0.052720598242332765.
# [I 2025-11-15 22:43:34,667] Trial 11 finished with value: 0.0507768130691498 and parameters: {'learning_rate': 0.07044414217640736, 'num_leaves': 148, 'max_depth': 14, 'subsample': 0.6061736291115143, 'colsample_bytree': 0.9363356027538656}. Best is trial 11 with value: 0.0507768130691498.
# [I 2025-11-15 22:46:53,290] Trial 12 finished with value: 0.05067551437510473 and parameters: {'learning_rate': 0.07621810483218196, 'num_leaves': 150, 'max_depth': 20, 'subsample': 0.664522673550441, 'colsample_bytree': 0.9923107144410297}. Best is trial 12 with value: 0.05067551437510473.
# [I 2025-11-15 22:48:12,465] Trial 13 finished with value: 0.09959461105885155 and parameters: {'learning_rate': 0.09558904664714249, 'num_leaves': 108, 'max_depth': 1, 'subsample': 0.6807969104645718, 'colsample_bytree': 0.9982155470020972}. Best is trial 12 with value: 0.05067551437510473.
# [I 2025-11-15 22:51:05,028] Trial 14 finished with value: 0.05561134729430298 and parameters: {'learning_rate': 0.06672748725116912, 'num_leaves': 141, 'max_depth': 11, 'subsample': 0.6063629477548319, 'colsample_bytree': 0.9993991935627737}. Best is trial 12 with value: 0.05067551437510473.
# [I 2025-11-15 22:53:31,817] Trial 15 finished with value: 0.05476387699354484 and parameters: {'learning_rate': 0.06990525487387504, 'num_leaves': 74, 'max_depth': 24, 'subsample': 0.7707976314253259, 'colsample_bytree': 0.876055132130735}. Best is trial 12 with value: 0.05067551437510473.
# [I 2025-11-15 22:56:27,057] Trial 16 finished with value: 0.05286456352021112 and parameters: {'learning_rate': 0.06549111159963382, 'num_leaves': 108, 'max_depth': 18, 'subsample': 0.6879123993727974, 'colsample_bytree': 0.832033319713438}. Best is trial 12 with value: 0.05067551437510473.
# [I 2025-11-15 22:58:45,662] Trial 17 finished with value: 0.08922484052061788 and parameters: {'learning_rate': 0.011435821563479488, 'num_leaves': 134, 'max_depth': 6, 'subsample': 0.6418366279004101, 'colsample_bytree': 0.9307810857194715}. Best is trial 12 with value: 0.05067551437510473.
# [I 2025-11-15 23:01:28,512] Trial 18 finished with value: 0.0509910486515137 and parameters: {'learning_rate': 0.08159849911394212, 'num_leaves': 116, 'max_depth': 27, 'subsample': 0.7999726829597469, 'colsample_bytree': 0.7443493867972419}. Best is trial 12 with value: 0.05067551437510473.
# [I 2025-11-15 23:04:29,919] Trial 19 finished with value: 0.0531187867914177 and parameters: {'learning_rate': 0.05434909955778507, 'num_leaves': 136, 'max_depth': 43, 'subsample': 0.9966721553175301, 'colsample_bytree': 0.9310826480734153}. Best is trial 12 with value: 0.05067551437510473.
# [I 2025-11-15 23:07:38,430] Trial 20 finished with value: 0.05131114309830382 and parameters: {'learning_rate': 0.056838449339089145, 'num_leaves': 150, 'max_depth': 16, 'subsample': 0.7042902199012093, 'colsample_bytree': 0.8744241814182027}. Best is trial 12 with value: 0.05067551437510473.
# [I 2025-11-15 23:10:26,749] Trial 21 finished with value: 0.05108772826569664 and parameters: {'learning_rate': 0.08098265788492708, 'num_leaves': 116, 'max_depth': 28, 'subsample': 0.7872585446083061, 'colsample_bytree': 0.7429208156595601}. Best is trial 12 with value: 0.05067551437510473.
# [I 2025-11-15 23:13:15,310] Trial 22 finished with value: 0.05088423454515052 and parameters: {'learning_rate': 0.07833107478827535, 'num_leaves': 123, 'max_depth': 22, 'subsample': 0.8989434193210489, 'colsample_bytree': 0.9653022284970949}. Best is trial 12 with value: 0.05067551437510473.
# [I 2025-11-15 23:16:07,304] Trial 23 finished with value: 0.05049002053933372 and parameters: {'learning_rate': 0.07782644376622212, 'num_leaves': 137, 'max_depth': 21, 'subsample': 0.9065216099631032, 'colsample_bytree': 0.9813140252359378}. Best is trial 23 with value: 0.05049002053933372.
# [I 2025-11-15 23:19:08,842] Trial 24 finished with value: 0.05291683259440686 and parameters: {'learning_rate': 0.060081950256675565, 'num_leaves': 139, 'max_depth': 12, 'subsample': 0.8872649474322309, 'colsample_bytree': 0.8291150934843887}. Best is trial 23 with value: 0.05049002053933372.
# [I 2025-11-15 23:21:54,800] Trial 25 finished with value: 0.08036442671993597 and parameters: {'learning_rate': 0.015177609291532489, 'num_leaves': 139, 'max_depth': 7, 'subsample': 0.9511739763868032, 'colsample_bytree': 0.9502577208849748}. Best is trial 23 with value: 0.05049002053933372.
# [I 2025-11-15 23:25:03,126] Trial 26 finished with value: 0.04855206015234097 and parameters: {'learning_rate': 0.09844065831999153, 'num_leaves': 150, 'max_depth': 21, 'subsample': 0.6441976583667873, 'colsample_bytree': 0.907325498051877}. Best is trial 26 with value: 0.04855206015234097.
# [I 2025-11-15 23:27:52,989] Trial 27 finished with value: 0.05226826403480675 and parameters: {'learning_rate': 0.08663396483550223, 'num_leaves': 103, 'max_depth': 32, 'subsample': 0.6532834956749606, 'colsample_bytree': 0.878154363287913}. Best is trial 26 with value: 0.04855206015234097.
# [I 2025-11-15 23:30:41,198] Trial 28 finished with value: 0.051387823510705165 and parameters: {'learning_rate': 0.09688966081786943, 'num_leaves': 127, 'max_depth': 20, 'subsample': 0.8436170368951779, 'colsample_bytree': 0.9991268494465659}. Best is trial 26 with value: 0.04855206015234097.
# [I 2025-11-15 23:33:43,984] Trial 29 finished with value: 0.05588084451438336 and parameters: {'learning_rate': 0.035852532815256896, 'num_leaves': 118, 'max_depth': 31, 'subsample': 0.9261715675134027, 'colsample_bytree': 0.8044307502157502}. Best is trial 26 with value: 0.04855206015234097.
# [I 2025-11-15 23:36:29,403] Trial 30 finished with value: 0.06521888239994411 and parameters: {'learning_rate': 0.0212085889864795, 'num_leaves': 73, 'max_depth': 36, 'subsample': 0.7156779531969882, 'colsample_bytree': 0.9056431034754838}. Best is trial 26 with value: 0.04855206015234097.
# [I 2025-11-15 23:39:31,581] Trial 31 finished with value: 0.05222204361504218 and parameters: {'learning_rate': 0.07210697407961122, 'num_leaves': 150, 'max_depth': 15, 'subsample': 0.6162853734227367, 'colsample_bytree': 0.9743213386905223}. Best is trial 26 with value: 0.04855206015234097.
# [I 2025-11-15 23:42:32,446] Trial 32 finished with value: 0.052089908032702706 and parameters: {'learning_rate': 0.06060371377819443, 'num_leaves': 142, 'max_depth': 25, 'subsample': 0.6394010060327644, 'colsample_bytree': 0.904939698798549}. Best is trial 26 with value: 0.04855206015234097.
# [I 2025-11-15 23:45:44,002] Trial 33 finished with value: 0.049805477973346814 and parameters: {'learning_rate': 0.09967891218103934, 'num_leaves': 143, 'max_depth': 22, 'subsample': 0.7578665832834128, 'colsample_bytree': 0.836823528518527}. Best is trial 26 with value: 0.04855206015234097.
# [I 2025-11-15 23:48:51,870] Trial 34 finished with value: 0.050869986168123056 and parameters: {'learning_rate': 0.086299585509149, 'num_leaves': 131, 'max_depth': 21, 'subsample': 0.7583013890628171, 'colsample_bytree': 0.8421407976783715}. Best is trial 26 with value: 0.04855206015234097.
# [I 2025-11-15 23:51:48,907] Trial 35 finished with value: 0.04974528507003216 and parameters: {'learning_rate': 0.09824190268156435, 'num_leaves': 132, 'max_depth': 28, 'subsample': 0.6907547506184982, 'colsample_bytree': 0.9042802204156339}. Best is trial 26 with value: 0.04855206015234097.
# [I 2025-11-15 23:54:37,963] Trial 36 finished with value: 0.051405039637303716 and parameters: {'learning_rate': 0.09258406549859993, 'num_leaves': 125, 'max_depth': 29, 'subsample': 0.8218185619094704, 'colsample_bytree': 0.7831965010897892}. Best is trial 26 with value: 0.04855206015234097.
# [I 2025-11-15 23:57:14,006] Trial 37 finished with value: 0.050690717158614916 and parameters: {'learning_rate': 0.09915443874420442, 'num_leaves': 91, 'max_depth': 24, 'subsample': 0.6989183769272709, 'colsample_bytree': 0.6697208379847188}. Best is trial 26 with value: 0.04855206015234097.
# [I 2025-11-16 00:00:14,789] Trial 38 finished with value: 0.0504936592743341 and parameters: {'learning_rate': 0.08326886455333898, 'num_leaves': 130, 'max_depth': 36, 'subsample': 0.77162226329463, 'colsample_bytree': 0.9115150509964481}. Best is trial 26 with value: 0.04855206015234097.
# [I 2025-11-16 00:03:34,832] Trial 39 finished with value: 0.0512686322247304 and parameters: {'learning_rate': 0.05190133604092195, 'num_leaves': 142, 'max_depth': 25, 'subsample': 0.7473425623652028, 'colsample_bytree': 0.7837533905702616}. Best is trial 26 with value: 0.04855206015234097.
# [I 2025-11-16 00:06:50,691] Trial 40 finished with value: 0.060794162687149614 and parameters: {'learning_rate': 0.02756413017993889, 'num_leaves': 111, 'max_depth': 17, 'subsample': 0.8231029897506158, 'colsample_bytree': 0.8460431793734768}. Best is trial 26 with value: 0.04855206015234097.
# [I 2025-11-16 00:10:07,663] Trial 41 finished with value: 0.05017319534114858 and parameters: {'learning_rate': 0.08428979788374451, 'num_leaves': 129, 'max_depth': 36, 'subsample': 0.7748321767265997, 'colsample_bytree': 0.9100062678049959}. Best is trial 26 with value: 0.04855206015234097.
# [I 2025-11-16 00:13:26,572] Trial 42 finished with value: 0.05115146954048355 and parameters: {'learning_rate': 0.08567356087243735, 'num_leaves': 134, 'max_depth': 41, 'subsample': 0.8595679943864325, 'colsample_bytree': 0.9010336609438996}. Best is trial 26 with value: 0.04855206015234097.
# [I 2025-11-16 00:16:32,165] Trial 43 finished with value: 0.05039361887432807 and parameters: {'learning_rate': 0.09827653029620666, 'num_leaves': 121, 'max_depth': 29, 'subsample': 0.7198403797749479, 'colsample_bytree': 0.5489867375818268}. Best is trial 26 with value: 0.04855206015234097.
# [I 2025-11-16 00:19:27,126] Trial 44 finished with value: 0.05143372752979394 and parameters: {'learning_rate': 0.09845365591526169, 'num_leaves': 124, 'max_depth': 34, 'subsample': 0.7159918701834433, 'colsample_bytree': 0.5101719094272383}. Best is trial 26 with value: 0.04855206015234097.
# [I 2025-11-16 00:22:05,468] Trial 45 finished with value: 0.052930932977868425 and parameters: {'learning_rate': 0.08937023628044155, 'num_leaves': 98, 'max_depth': 39, 'subsample': 0.6795792321961889, 'colsample_bytree': 0.5581103635512927}. Best is trial 26 with value: 0.04855206015234097.
# [I 2025-11-16 00:25:43,302] Trial 46 finished with value: 0.05194015751963828 and parameters: {'learning_rate': 0.06310775727266978, 'num_leaves': 144, 'max_depth': 30, 'subsample': 0.7334089113349889, 'colsample_bytree': 0.6176765604848032}. Best is trial 26 with value: 0.04855206015234097.
# [I 2025-11-16 00:27:56,024] Trial 47 finished with value: 0.062051322280256234 and parameters: {'learning_rate': 0.07334840899163113, 'num_leaves': 29, 'max_depth': 43, 'subsample': 0.7215376617512328, 'colsample_bytree': 0.7029687417481482}. Best is trial 26 with value: 0.04855206015234097.
# [I 2025-11-16 00:29:57,030] Trial 48 finished with value: 0.07406035336748294 and parameters: {'learning_rate': 0.02248110773269639, 'num_leaves': 50, 'max_depth': 27, 'subsample': 0.7555722225614666, 'colsample_bytree': 0.44097902990504834}. Best is trial 26 with value: 0.04855206015234097.
# [I 2025-11-16 00:33:01,368] Trial 49 finished with value: 0.05519922400331413 and parameters: {'learning_rate': 0.04491973601231058, 'num_leaves': 121, 'max_depth': 34, 'subsample': 0.6321739164070189, 'colsample_bytree': 0.5280474211307005}. Best is trial 26 with value: 0.04855206015234097.
# --- Tuning Complete ---
# Best trial:
#   Value (RMSE): 0.0486
#   Best Params:
#     learning_rate: 0.09844065831999153
#     num_leaves: 150
#     max_depth: 21
#     subsample: 0.6441976583667873
#     colsample_bytree: 0.907325498051877

# %%
# 1. Get the best parameters from the Optuna study
# This assumes 'study' is in memory from the previous cell

# --- Tuning Complete ---
# Best trial:
#   Value (RMSE): 0.0486
#   Best Params: 
#     learning_rate: 0.09844065831999153
#     num_leaves: 150
#     max_depth: 21
#     subsample: 0.6441976583667873
#     colsample_bytree: 0.907325498051877
best_params = study.best_params

# 2. Set our fixed parameters and combine with the best ones
# We also add the 'l1' (MAE) metric back in for logging
final_params = {
    'objective': 'regression_l1', 
    'metric': ['rmse', 'l1'],
    'n_estimators': 10000, # high number, early stopping will find the best
    'n_jobs': -1,
    'seed': 42,
    'verbose': -1,
    **best_params  # This unpacks 'learning_rate', 'num_leaves', etc.
}

# 3. Define Callbacks
callbacks = [
    lgb.log_evaluation(period=100), 
    lgb.early_stopping(stopping_rounds=50, first_metric_only=True)
]

# 4. Train the *final* model
print("Training final model with best parameters...")
model = lgb.train(
    params=final_params,
    train_set=train_data,
    valid_sets=[train_data, val_data], 
    valid_names=['train', 'validation'],
    callbacks=callbacks
)

print("\n--- Final Model Training Complete ---")
print(f"Best iteration: {model.best_iteration}")
print(f"Best validation score (RMSE): {model.best_score['validation']['rmse']:.4f}")
print(f"Best validation score (MAE/l1): {model.best_score['validation']['l1']:.4f}")
# Out:
# Training final model with best parameters...
# Training until validation scores don't improve for 50 rounds
# [100]	train's rmse: 0.0989961	train's l1: 0.0356865	validation's rmse: 0.0747737	validation's l1: 0.0307522
# [200]	train's rmse: 0.0803788	train's l1: 0.0305159	validation's rmse: 0.0628219	validation's l1: 0.0265726
# [300]	train's rmse: 0.0712909	train's l1: 0.0283013	validation's rmse: 0.0573841	validation's l1: 0.0248473
# [400]	train's rmse: 0.065517	train's l1: 0.0268175	validation's rmse: 0.0538585	validation's l1: 0.0237482
# [500]	train's rmse: 0.0628689	train's l1: 0.0260752	validation's rmse: 0.0525994	validation's l1: 0.0232745
# [600]	train's rmse: 0.0593594	train's l1: 0.0252022	validation's rmse: 0.05114	validation's l1: 0.0228151
# [700]	train's rmse: 0.0582236	train's l1: 0.0247915	validation's rmse: 0.0503945	validation's l1: 0.022552
# [800]	train's rmse: 0.0569004	train's l1: 0.024378	validation's rmse: 0.0496425	validation's l1: 0.0223145
# [900]	train's rmse: 0.0558494	train's l1: 0.0240106	validation's rmse: 0.0490878	validation's l1: 0.0221221
# [1000]	train's rmse: 0.0549246	train's l1: 0.0236909	validation's rmse: 0.0485521	validation's l1: 0.0219392
# [1100]	train's rmse: 0.0537009	train's l1: 0.0233195	validation's rmse: 0.0481673	validation's l1: 0.021821
# [1200]	train's rmse: 0.0529333	train's l1: 0.0230592	validation's rmse: 0.0477641	validation's l1: 0.0216942
# [1300]	train's rmse: 0.0522491	train's l1: 0.0228217	validation's rmse: 0.0475454	validation's l1: 0.021608
# [1400]	train's rmse: 0.0518273	train's l1: 0.0226477	validation's rmse: 0.0472455	validation's l1: 0.0215182
# [1500]	train's rmse: 0.0514093	train's l1: 0.0224875	validation's rmse: 0.0471279	validation's l1: 0.0214843
# [1600]	train's rmse: 0.0511122	train's l1: 0.0223547	validation's rmse: 0.0470116	validation's l1: 0.0214297
# [1700]	train's rmse: 0.050717	train's l1: 0.0222025	validation's rmse: 0.0469187	validation's l1: 0.0213969
# [1800]	train's rmse: 0.0501534	train's l1: 0.0220087	validation's rmse: 0.0467478	validation's l1: 0.0213375
# [1900]	train's rmse: 0.0498174	train's l1: 0.0218654	validation's rmse: 0.046622	validation's l1: 0.0212884
# [2000]	train's rmse: 0.0495298	train's l1: 0.0217343	validation's rmse: 0.0464836	validation's l1: 0.0212358
# Early stopping, best iteration is:
# [2019]	train's rmse: 0.0494874	train's l1: 0.0217109	validation's rmse: 0.0464519	validation's l1: 0.0212243
# Evaluated only: rmse
#
# --- Final Model Training Complete ---
# Best iteration: 2019
# Best validation score (RMSE): 0.0465
# Best validation score (MAE/l1): 0.0212

# %%
# --- 9. Load, Concat, and Impute Test Set ---

TEST_DATA_PATH = "df_test.csv"

print(f"Loading complete test data from {TEST_DATA_PATH}...")
test_df = pd.read_csv(TEST_DATA_PATH)

# --- 1. Prep Test Set ---
test_df[TIME_COLUMN] = pd.to_datetime(test_df[TIME_COLUMN])
for col in CATEGORICAL_FEATURES:
    if col in test_df.columns:
        # Use the categories from the training data to ensure consistency
        test_df[col] = pd.Categorical(
            test_df[col], 
            categories=data[col].dtype.categories
        )

# --- 2. Get History & Concatenate ---
min_test_date = test_df[TIME_COLUMN].min()
history_cutoff = min_test_date - pd.Timedelta(days=8) # 8 days to be safe
history_df = data[data[TIME_COLUMN] >= history_cutoff].copy()

print(f"History data shape: {history_df.shape}")
print(f"Test data shape: {test_df.shape}")

combined_df = pd.concat([history_df, test_df], ignore_index=True)
combined_df = combined_df.sort_values(by=[GROUP_COLUMN, TIME_COLUMN])

# --- 3. Impute ALL Missing Future Data ---
print("Imputing missing data...")

# A. Impute 'eur_per_mwh' (for Oct 2nd)
# Shift(24) here, as it's the most logical way to get Oct 2nd's price
print("Imputing prices using 24-hour lag...")
combined_df['eur_per_mwh'] = combined_df.groupby(GROUP_COLUMN)['eur_per_mwh'].transform(
    lambda x: x.fillna(x.shift(24))
)

# B. Impute all weather columns (for Oct 1st & 2nd)
print("Imputing weather using 48-hour rolling mean...")
WEATHER_COLUMNS = ['avg_temp', 'avg_hum', 'wind', 'rain', 'air_pressure']
for col in WEATHER_COLUMNS:
    if col in combined_df.columns:
        combined_df[col] = combined_df.groupby(GROUP_COLUMN)[col].transform(
            # For each group:
            # 1. Calculate a rolling 48h mean (using min_periods=1 for the start)
            # 2. Shift it by 1 so the mean is from the *past* (no data leakage)
            # 3. Use this rolling mean ONLY to fill the NaNs
            lambda x: x.fillna(x.shift(1).rolling(window=48, min_periods=1).mean())
        )
    
# C. Final cleanup (in case any group had no data at all)
combined_df = combined_df.fillna(method='ffill')

print("Imputation complete. 'combined_df' is ready for feature engineering.")
# Out:
# Loading complete test data from df_test.csv...
# History data shape: (21504, 82)
# Test data shape: (5376, 15)
# Imputing missing data...
# Imputing prices using 24-hour lag...
# Imputing weather using 48-hour rolling mean...
# Imputation complete. 'combined_df' is ready for feature engineering.
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/603029108.py:35: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   combined_df['eur_per_mwh'] = combined_df.groupby(GROUP_COLUMN)['eur_per_mwh'].transform(
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/603029108.py:45: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   combined_df[col] = combined_df.groupby(GROUP_COLUMN)[col].transform(
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/603029108.py:54: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_df = combined_df.fillna(method='ffill')

# %%
# 1. Get the last 7 days (168h) of training data.
min_test_date = test_df[TIME_COLUMN].min()
history_cutoff = min_test_date - pd.Timedelta(days=8) # 8 days to be safe
history_df = data[data[TIME_COLUMN] >= history_cutoff].copy()

print(f"History data shape: {history_df.shape}")
print(f"Test data shape: {test_df.shape}")

# 2. Combine the history and the test set
combined_df = pd.concat([history_df, test_df], ignore_index=True)

# 3. Re-run all feature engineering functions
print("Creating time features...")
combined_df = create_time_features(combined_df)

print("Creating CONSUMPTION features...")
combined_df = create_lag_features(combined_df, GROUP_COLUMN, TARGET_COLUMN, lag_list)
combined_df = create_rolling_features(combined_df, GROUP_COLUMN, TARGET_COLUMN, window_list, agg_list)

print("Creating PRICE features...")
combined_df = create_lag_features(combined_df, GROUP_COLUMN, 'eur_per_mwh', price_lag_list)
combined_df = create_rolling_features(combined_df, GROUP_COLUMN, 'eur_per_mwh', price_window_list, price_agg_list)

print("Creating WEATHER features...")
WEATHER_COLUMNS = ['avg_temp', 'avg_hum', 'wind', 'rain', 'air_pressure']
weather_lag_list = [1, 24, 168]
weather_window_list = [24, 168]
weather_agg_list = ['mean', 'std']

for col in WEATHER_COLUMNS:
    print(f"Creating test features for: {col}")
    combined_df = create_lag_features(combined_df, GROUP_COLUMN, col, weather_lag_list)
    combined_df = create_rolling_features(combined_df, GROUP_COLUMN, col, weather_window_list, weather_agg_list)

print("Feature engineering complete.")
# Out:
# History data shape: (21504, 82)
# Test data shape: (5376, 15)
# Creating time features...
# Creating time features (with cyclic)...
# Creating CONSUMPTION features...
# Creating lag features for lags: [1, 2, 3, 6, 12, 24, 48, 168]...
# Creating rolling features for windows: [24, 168]...
# Creating PRICE features...
# Creating lag features for lags: [1, 24, 168]...
# Creating rolling features for windows: [24, 168]...
# Creating WEATHER features...
# Creating test features for: avg_temp
# Creating lag features for lags: [1, 24, 168]...
# Creating rolling features for windows: [24, 168]...
# Creating test features for: avg_hum
# Creating lag features for lags: [1, 24, 168]...
# Creating rolling features for windows: [24, 168]...
# Creating test features for: wind
# Creating lag features for lags: [1, 24, 168]...
# Creating rolling features for windows: [24, 168]...
# Creating test features for: rain
# Creating lag features for lags: [1, 24, 168]...
# Creating rolling features for windows: [24, 168]...
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:78: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = df_copy.groupby(group_col)
# /var/folders/_f/wnkmlt6119513l1gty6gcf480000gn/T/ipykernel_60345/2398829984.py:97: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rolling_feat = df_copy.groupby(group_col)[target] \
# Creating test features for: air_pressure
# Creating lag features for lags: [1, 24, 168]...
# Creating rolling features for windows: [24, 168]...
# Feature engineering complete.

# %%
# 1. Isolate the test set rows (they are the last N rows)
final_test_features = combined_df.tail(len(test_df))

# 2. Separate features (X_test) and true target (y_test)
X_test = final_test_features[features]
y_test = final_test_features[TARGET_COLUMN]

# 3. Generate Predictions
print("Generating predictions on test set...")
test_predictions = model.predict(X_test)

# 4. Calculate Final Test Scores
test_rmse = np.sqrt(mean_squared_error(y_test, test_predictions))
test_mae = mean_absolute_error(y_test, test_predictions)
test_mape = mean_absolute_percentage_error(y_test, test_predictions)

print("\n--- Final Test Set Performance ---")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test MAE:  {test_mae:.4f}")
print(f"Test MAPE: {test_mape:.4f}")
# Out:
# Generating predictions on test set...
#
# --- Final Test Set Performance ---
# Test RMSE: 1.9063
# Test MAE:  1.5665
# Test MAPE: 3.6077
